# %%
image = cv2.imread('one.jpeg')
plt.imshow(image)
b,g,r=cv2.split(image)
merged=cv2.merge([r,g,b])
plt.imshow(merged)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-40f9bd4bc610> in <module>()
#       1 image = cv2.imread('one.jpeg')
# ----> 2 plt.imshow(image)
#       3 b,g,r=cv2.split(image)
#       4 merged=cv2.merge([r,g,b])
#       5 plt.imshow(merged)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
print("Altura")
print(imagem.shape[0])

print("Largura")
print(imagem.shape[1])

print("Canais")
print(imagem.shape[2])
# Out:
# Altura
# 853
# Largura
# 1280
# Canais
# 3

# %%
(b,g,r) = imagem [0,0]
print("Cor do pixel em (0,0)")
print("Vermelho:", r)
print("Verde:", g)
print("Azul:", b)
# Out:
# Cor do pixel em (4,4)
# Vermelho: 0
# Verde: 9
# Azul: 4

# %%
#Modificando o pixel de uma imagem.
imagem [0,0] = (255, 0, 0)
imagem [10:50, 10:50] = (0, 0, 255)
plt.imshow(imagem)

# %%
import numpy as np
altura = 300
largura = 300
canais = 3 
cores = (117, 84, 63)
pixel_array = np.full((altura, largura, canais), cores, dtype=np.uint8)
plt.imshow(pixel_array)

# %%
# Lendo a imagem
ruido2 = cv2.imread('one.jpeg')
plt.imshow(ruido2)

# Aplicando o filtro de mediana da biblioteca OpenCV
# que é importada como cv2 e atribuindo a variavel median
# utilizando uma mascara 5x5
median = cv2.medianBlur(ruido2,5)

# Codigo reponsavel por plotar a imagem original e 
# o resultado lado a lado a nivel de comparacao
plt.subplot(121),plt.imshow(ruido2),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(median),plt.title('Mediana')
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5dac2474e830> in <module>()
#       3 # Lendo a imagem
#       4 ruido2 = cv2.imread('one.jpeg')
# ----> 5 plt.imshow(ruido2)
#       6
#       7 # Aplicando o filtro de mediana da biblioteca OpenCV
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
imagem

# %%
wget --no-check-certificate \
    https://www.hypeness.com.br/1/2017/01/fotos1.jpg
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/maxbassoul/opencv-learning/main/common.py \
    -O common.py


import cv2 #opencv itself
import common #some useful opencv functions
import numpy as np # matrix manipulations


# %matplotlib inline 
from matplotlib import pyplot as plt 

pylab.rcParams['figure.figsize'] = (10.0, 8.0)
